# %%
import os

# /home/pumengyu/twostage_medseg/scripts/学习/test.ipynb
_home = os.path.expanduser("~")  # 把~符号展开成当前的用户的家目录路径
# Linux上,~是家目录的简写,expanduser函数会将~替换为实际路径字符串
# os.path.expanduser("~/data") 输出/home/username/data

# 家目录是Linux给每个用户分配的专属目录,用来存放个人文件和配置
# ~是shell里的简写符号,~会被shell自动替换为当前用户的家目录路径
print(_home)
print("~")
# cat是终端命令,打印文件内容到屏幕,
# ~/.profile指代/home/pumengyu/.profile文件,
# .profile的作用是,登录时候,bash会自当读取并且执行这个文件的命令,通常来设置环境变量,PATH之类的初始化设置,
#
# Out:
# /home/pumengyu
# ~

# %% [markdown]
# # ~/.profile: executed by the command interpreter for login shells.
# # This file is not read by bash(1), if ~/.bash_profile or ~/.bash_login
# # exists.
# # see /usr/share/doc/bash/examples/startup-files for examples.
# # the files are located in the bash-doc package.
#
# # the default umask is set in /etc/profile; for setting the umask
# # for ssh logins, install and configure the libpam-umask package.
# #umask 022
# ```bash
#
# # if running bash
# if [ -n "$BASH_VERSION" ]; then
#     # include .bashrc if it exists
#     if [ -f "$HOME/.bashrc" ]; then
# 	. "$HOME/.bashrc"
#     fi
# fi
#
# # set PATH so it includes user's private bin if it exists
# if [ -d "$HOME/bin" ] ; then
#     PATH="$HOME/bin:$PATH"
# fi
#
# # set PATH so it includes user's private bin if it exists
# if [ -d "$HOME/.local/bin" ] ; then
#     PATH="$HOME/.local/bin:$PATH"
# fi

# %% [markdown]
# ```bash
# -f :判断是不是一个文件file
#
# -d 判断是不是一个目录directory
#
# -n 判断是否非空non-empty
#
# ~/bin
#
# ~/.local/bin
#
# if [条件];then
#      #do something
# fi
#
# . ~/.bashrc 等价于source ~/.bashrc 相当于在当前的shell执行这个文件
# Linux系统:bash(shell,命令解释器):终端直接输入命令,.sh文件是把命令写进文件批量执行,叫做shell脚本
#
#
# #PATH是环境变量,用来指定shell执行命令时去哪些目录下找可执行文件
# echo $PATH
# #输出 echo是打印的意思,cat是
#
# echo:打印文字,cat 打印文件

# %% [markdown]
# ```bash
# bash ,linux,python本质都是c语言,不是c++,
# c++=c语言+面向对象编程+更多特性
# Linux内核,bash,Python解释器,都是C语言写的,
# Pytorch底层是c++,因为c++性能和c接近,但是写起来更方便,适合大型项目

# %% [markdown]
# ### 三级标题,中间必须留下空格
# #### 四级标题,
# ##### 五级标题
#
# **粗体** *斜体* ***粗斜体***  ~~删除线~~
#
# 无序列表(用-或*):
#
# - 苹果
# - 香蕉
# - 橙子
#
# 有序列表(用数字):
#
# 1.第一步
#
# 2.第二步
#
# 3.第三步
#
# 嵌套:缩进两格
#
# - 水果
#   - 苹果
#   - 香蕉
#   - 橙子
#
# 代码块:用三个反引号包围,可以指定语言
#
# ```python
#
# print("hello world")
# ```
# [百度](https://www.baidu.com)
#
# [Github](https://github.com)
#
# [樱花动漫](https://www.yinghuadongman.com.cn/h/1/)
#
# > 引用什么
# > 这是
#
# ---
#
# 这个是分割线---或者是***
#
# 表格
# |姓名|年龄|性别|
# |---|---|---|
# |张三|20|男|
# |李四|25|女|
# |王五|30|男|
#
# \*这个是转义字符,
#
# $L=-\sum y\log \hat{y}$
# $$
# \frac{\partial L}{\partial w} = \frac{1}{N} \sum_{i=1}^{N} (y_i - \hat{y}_i) x_i
# $$
# 你好<br> 第二行<br>第三行<br>第四行
